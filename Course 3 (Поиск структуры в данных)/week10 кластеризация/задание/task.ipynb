# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_table(r'C:\Users\One\Git\COURSERA YANDEX\Course 3\week10\задание\checkins.dat', sep='|', 
                     skipinitialspace = True, header=[0], skiprows=[1])
data.dropna(axis='rows', inplace=True)

# %%
cols = list([x.replace(' ', '') for x in data.columns])
data.columns = cols

# %%
X=np.array((data['latitude'].head(100000), data['longitude'].head(100000))).T

# %%
from sklearn.cluster import MeanShift, estimate_bandwidth
ms = MeanShift(bandwidth=0.1)
ms.fit(X)
# Out:
# MeanShift(bandwidth=0.1, bin_seeding=False, cluster_all=True, min_bin_freq=1,
#      n_jobs=None, seeds=None)

# %%
cluster_centers = ms.cluster_centers_
offices = [[33.751277, -118.188740], [25.867736, -80.324116],[51.503016, -0.075479],[52.378894, 4.885084],[39.366487, 117.036146],[-33.868457, 151.205134]]

# %%
with open("cluster_centers.txt", "w") as fout:
        fout.write(" ".join([str(num) for num in cluster_centers]))

# %%
dist_0, dist_1, dist_2, dist_3, dist_4, dist_5 = [], [], [], [], [], []

for i in range(len(cluster_centers)):
        dist_0.append(((cluster_centers[i][0] - offices[0][0])**2 + (cluster_centers[i][1] - offices[0][1])**2)**0.5)
for i in range(len(cluster_centers)):
        dist_1.append(((cluster_centers[i][0] - offices[1][0])**2 + (cluster_centers[i][1] - offices[1][1])**2)**0.5)
for i in range(len(cluster_centers)):
        dist_2.append(((cluster_centers[i][0] - offices[2][0])**2 + (cluster_centers[i][1] - offices[2][1])**2)**0.5)        
for i in range(len(cluster_centers)):
        dist_3.append(((cluster_centers[i][0] - offices[3][0])**2 + (cluster_centers[i][1] - offices[3][1])**2)**0.5)
for i in range(len(cluster_centers)):
        dist_4.append(((cluster_centers[i][0] - offices[4][0])**2 + (cluster_centers[i][1] - offices[4][1])**2)**0.5)
for i in range(len(cluster_centers)):
        dist_5.append(((cluster_centers[i][0] - offices[5][0])**2 + (cluster_centers[i][1] - offices[5][1])**2)**0.5)

# %%
dist_cc = pd.DataFrame(cluster_centers)
dist_cc.columns = [['latitude', 'longitude']]

# %%
dist_cc['dist_1'] = dist_1
dist_cc['dist_2'] = dist_2
dist_cc['dist_3'] = dist_3
dist_cc['dist_4'] = dist_4
dist_cc['dist_5'] = dist_5
dist_cc['dist_0'] = dist_0

# %%
dist_cc
# Out:
#        latitude   longitude      dist_1      dist_2      dist_3      dist_4  \
# 0     40.717716  -73.991835   16.143720   74.699066   79.734255  191.032760
# 1     33.449438 -112.002140   32.572679  113.373317  118.410081  229.114704
# 2     33.446380 -111.901888   32.474475  113.274833  118.311609  229.014565
# 3     41.878244  -87.629843   17.598580   88.081797   93.108944  204.681402
# 4     37.688682 -122.409330   43.713842  123.111360  128.139261  239.451355
# 5     38.886165  -77.048783   13.424131   78.000478   83.037415  194.085524
# 6     33.357345 -111.822654   32.376722  113.210850  118.247687  228.937678
# 7     33.766636  -84.393289    8.885426   86.163056   91.197829  201.507260
# 8     42.363219  -71.073688   18.912202   71.584087   76.616243  188.133702
# 9     47.606245 -122.332044   47.299353  122.318651  127.306621  239.509966
# 10    36.117229 -115.171073   36.323031  116.119414  121.152477  232.229952
# 11    34.060398 -118.248709   38.799413  119.453578  124.488948  235.344678
# 12    44.977948  -93.267301   23.080863   93.419977   98.431015  210.378298
# 13    30.267184  -97.743119   17.965991   99.949630  104.983217  214.971929
# 14    40.766876  -73.833353   16.251596   74.535151   79.570292  190.874637
# 15    39.735830 -104.986580   28.294190  105.568963  110.596698  222.023034
# 16    39.951680  -75.162736   14.999911   75.970583   81.006723  192.199773
# 17    34.035487 -118.438998   38.980205  119.645464  124.680831  235.535481
# 18    32.980893 -117.078118   37.435994  118.459641  123.496174  234.201333
# 19    32.803021  -96.769897   17.848302   98.486042  103.522703  213.906763
# 20    37.347871 -121.947287   43.177331  122.691099  127.719936  238.991958
# 21    28.543502  -81.376429    2.875254   84.480671   89.493991  198.707541
# 22    32.711344 -117.153639   37.459962  118.576652  123.613358  234.284328
# 23    32.221713 -110.926535   31.255097  112.515445  117.552725  228.074619
# 24    34.127402 -118.351884   38.914434  119.545890  124.581167  235.446326
# 25    29.762698  -95.382314   15.553779   97.754970  102.786397  212.635450
# 26    43.040533  -87.914333   18.775418   88.245554   93.268090  204.983407
# 27    33.817306 -117.891249   38.399026  119.135805  124.171496  234.992924
# 28    37.390292 -122.087286   43.323570  122.825283  127.853983  239.131598
# 29    25.785812  -80.217938    0.134109   84.167620   89.161182  197.721037
# ...         ...         ...         ...         ...         ...         ...
# 3201  -6.814043  107.948844  191.088477  122.760473  118.852608   47.066128
# 3202  -7.150975  110.140259  193.305234  124.851110  120.923353   47.025818
# 3203  -7.248418  107.909650  191.124646  122.932986  119.035614   47.499918
# 3204  -7.431518  109.247398  192.473892  124.196500  120.286233   47.441731
# 3205  -7.566667  110.816667  194.042928  125.643525  121.716763   47.343456
# 3206  -8.129379  115.091301  198.350672  129.689667  125.724546   47.535668
# 3207  -8.184486  113.668075  196.958178  128.453081  124.505671   47.670105
# 3208 -11.202692   17.873887  104.962205   65.224118   64.894738  111.312153
# 3209 -13.525000  -71.972222   40.268372   96.942171  101.244105  196.269388
# 3210 -17.930178  -43.790845   57.034526   82.048776   85.514395  170.728524
# 3211 -19.815731  -43.954223   58.393050   83.735941   87.162731  171.523857
# 3212 -20.450000  -49.866667   55.434546   87.500851   91.114225  177.297944
# 3213 -21.211545  -50.426136   55.770493   88.445441   92.059132  178.082323
# 3214 -22.957640   18.490410  110.219000   76.740351   76.555197  116.599995
# 3215 -23.030939  -45.548324   60.003634   87.310308   90.720292  174.146916
# 3216 -25.252089  -52.021541   58.431774   92.680848   96.254525  180.986359
# 3217 -26.111602  -49.806865   60.275651   92.180473   95.665914  179.231611
# 3218 -26.381700  153.098379  239.198798  171.837888  167.840436   74.988725
# 3219 -29.772121   30.806820  124.281449   86.944604   86.143634  110.524404
# 3220 -30.810192  121.536292  209.666430  146.849879  143.275707   70.320819
# 3221 -32.020034  115.932843  204.616196  142.947650  139.480406   71.395046
# 3222 -32.890183  -68.844050   59.868898  108.863807  112.724446  199.430373
# 3223 -33.900000   18.633333  115.606051   87.428227   87.367396  122.682891
# 3224 -34.455906  -58.908329   64.012325  104.164488  107.749162  190.804098
# 3225 -35.308056  149.124444  237.463933  172.617436  168.801642   81.276972
# 3226 -36.506376  148.301203  236.981152  172.514616  168.726923   82.062142
# 3227 -37.713377  145.148916  234.266187  170.439695  166.705009   82.046531
# 3228 -37.822983  145.181190  234.327017  170.524585  166.791415   82.160561
# 3229 -41.292495  174.773235  263.789983  197.947164  194.000807   99.193965
# 3230 -45.031162  168.662644  258.884260  194.400107  190.556574   98.935628
#
#           dist_5      dist_0
# 0     237.227259   44.742571
# 1     271.679532    6.193959
# 2     271.581649    6.294241
# 3     250.558794   31.621097
# 4     282.816724    5.772048
# 5     239.568541   41.459174
# 6     271.482828    6.378262
# 7     245.114510   33.795454
# 8     234.987538   47.895654
# 9     285.413235   14.461227
# 10    275.416558    3.834585
# 11    277.884333    0.314884
# 12    256.872589   27.333428
# 13    257.077057   20.740355
# 14    237.092290   44.906781
# 15    266.555408   14.495237
# 16    238.100452   43.470473
# 17    278.062769    0.378688
# 18    276.486417    1.351655
# 19    256.781429   21.439823
# 20    282.283564    5.202131
# 21    240.809958   37.178854
# 22    276.494667    1.467274
# 23    270.334834    7.421535
# 24    278.000760    0.409983
# 25    254.665061   23.152577
# 26    251.183423   31.667492
# 27    277.478334    0.304731
# 28    282.429737    5.333020
# 29    238.988013   38.797299
# ...          ...         ...
# 3201   51.020074  229.747148
# 3202   48.991303  231.963631
# 3203   50.824457  229.785676
# 3204   49.591969  231.134635
# 3205   48.197640  232.702920
# 3206   44.347594  237.009635
# 3207   45.482933  235.618740
# 3208  135.244069  143.296538
# 3209  224.102630   66.113636
# 3210  195.646264   90.587083
# 3211  195.664646   91.543366
# 3212  201.519042   87.210573
# 3213  202.028133   87.250686
# 3214  133.162472  147.976658
# 3215  197.051706   92.200055
# 3216  203.409251   88.653795
# 3217  201.161608   90.882590
# 3218    7.722429  277.871690
# 3219  120.467979  161.971908
# 3220   29.826049  248.266538
# 3221   35.320691  243.184664
# 3222  220.051358   82.921545
# 3223  132.571804  152.633466
# 3224  210.114284   90.368064
# 3225    2.530161  276.089714
# 3226    3.923192  275.595768
# 3227    7.173645  272.862452
# 3228    7.205982  272.922324
# 3229   24.709750  302.420711
# 3230   20.721260  297.473342
#
# [3231 rows x 8 columns]
