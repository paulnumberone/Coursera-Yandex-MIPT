# %%
import pandas as pd
milk = pd.read_csv(r'C:\Users\One\Git\COURSERA YANDEX\Course 5\week 18\monthly-milk-production.csv',';', index_col=['month'], parse_dates=['month'], dayfirst=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(milk)

# %%
import statsmodels.api as sm
sm.tsa.stattools.adfuller(milk.milk)
# Out:
# (-1.3038115874221274,
#  0.6274267086030326,
#  13,
#  154,
#  {'1%': -3.473542528196209,
#   '5%': -2.880497674144038,
#   '10%': -2.576878053634677},
#  1115.1730447395112)

# %%
round(0.6274267086030326, 2)
# Out:
# 0.63

# %%
milk = pd.read_csv(r'C:\Users\One\Git\COURSERA YANDEX\Course 5\week 18\monthly-milk-production.csv',';', parse_dates=['month'], dayfirst=True)

# %%
from calendar import monthrange as mr

# %%
capitalizer = lambda x: x.days_in_month
milk['days'] = milk['month'].map(capitalizer)

# %%
milk['avg'] = milk.milk / milk.days

# %%
plt.plot(milk['month'], milk['avg'])

# %%
round(sum(milk['avg']), 2)
# Out:
# 4166.33
